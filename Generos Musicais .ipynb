# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
genero = ["Rock", "Hip Hop", "Pop", "Jazz"]
quantidade_msc = [330, 570, 233, 190]

plt.style.use("dark_background")


plt.title("Popularidade/Quantidade dos Gêneros Musicais do DataSet")
plt.bar(genero, quantidade_msc, color='purple', edgecolor='white')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.style.use("dark_background")

plt.title("Popularidade dos Gêneros Musicais do DataSet")
plt.barh(genero, quantidade_msc, color='yellow', edgecolor='white')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.style.use("default")

cores = sns.color_palette("Reds")

plt.title('Quantidade de Musicas dos Gêneros Musicais em Porcentagem')
plt.pie(quantidade_msc, labels=genero, autopct='%1.1f%%', colors=(cores))
plt.show()

# %%
plt.style.use("dark_background")

cores = sns.color_palette("cool")

plt.title('Quantidade de Musicas dos Gêneros Musicais em Porcentagem')
plt.pie(quantidade_msc, labels=genero, autopct='%1.1f%%', colors=(cores))
plt.show()

# %%
   
plt.style.use("dark_background")

cores = sns.color_palette("dark:salmon_r")

plt.title('Quantidade de Musicas dos Gêneros Musicais em Porcentagem')
plt.pie(quantidade_msc, labels=genero, autopct='%1.1f%%', colors=(cores))
plt.show()
